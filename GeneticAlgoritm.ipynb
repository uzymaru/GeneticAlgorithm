# %% [markdown]
# <a href="https://colab.research.google.com/github/uzymaru/GeneticAlgorithm/blob/main/GeneticAlgoritm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math 
import random

# %%
class Algoritma_genetika :
# membuat algoritma genetika
# misalkan ada persamaan a+2b+3c+4d = 30
# maka buat algoritma genetika untuk mencari nilai a,b,c, dan d

	jum_chrom = 6 #jumlah chromosome
	gen = ["a", "b", "c", "d"] #nilai gen abcd
	nilai_per_gen = {
		'min' : 0,
		'max' : 10
	} #nilai per gen 0-10
	crossover_rate = 50/100 #persen
	mutasi_rate = 10/100 #persen
	total_gen = 24
# total_gen     = (jumlah gen dalam chromosome) * jumlah populasi
# = 4 * 6
# = 24
	next_gen = np.arange(4)
	stop = False

#inisialisasi chromosome secara random    
	def __init__(self):
		self.first_chrom = np.random.randint(low=self.nilai_per_gen['min'], high=self.nilai_per_gen['max'], size=(self.jum_chrom, len(self.gen)))
		print("==================================================inisialisasi=================================================")
		print(self.first_chrom)
		print("---------------------------------------------------------------------------------------------------------------")

#evaluasi chromosome
	def evaluasi_chrom(self, chrom, generasi):
		# mencari fungsi objektif
		# fungsi_objektif(chromosome) = | (a+2b+3c+4d) – 30 |
		print("GENERASI ["+str(generasi+1)+"] ------")
		
		jum_chromo = len(chrom)
		o = np.arange(jum_chromo)   
		fitness = np.arange(jum_chromo, dtype='f')
		
		for x in range(len(chrom)):
		
			#FUNGSI OBJEKTIF 
			#fo=fungsi_objektif(chromosome[x])=o[x]
			fo = abs((chrom[x][0]+2*chrom[x][1]+3*chrom[x][2]+4*chrom[x][3])-30)
			o[x] = fo
			
			#SELEKSI CHROMOSOME, DAN MENCARI FITNESS
			fitn = 1/(fo+1)
			
			fitness[x] = fitn
			if(fitn == 1):
				self.stop = True
			print("CHROMOSOME {0} : {1}, fitness = {2}".format(x+1, np.array2string(chrom[x], separator=','), fitn))
		print("FITNESS SELESAI!!")
		print(o)
		
        
#probabilitas
		Probab = np.arange(jum_chromo, dtype='f')
		# print(fitness)
		total_fitness = fitness.sum() #rumus total fitness
		Probab = fitness / total_fitness #rumus mencari probabilitas
		print("Total fitness : {}".format(str(total_fitness)))
		print("Rata-rata fitness : {}".format(str(np.average(fitness))))
		print("Probabilitas : {}".format(np.array2string(Probab, separator=',')))
		print("Probabilitas Paling Tinggi : {}, Pada chromosome ke {}".format(Probab[Probab.argmax()], str(Probab.argmax()+1)))
		print("CHROMOSOME YANG MUNGKIN TERPILIH : {}".format(np.array2string(chrom[Probab.argmax()], separator=',')))
		print("")
		print("")
		self.next_gen = chrom[Probab.argmax()]

#seleksi dengan ROULETE WHELL (C) dari cumulative probabilitas
		C = np.arange(jum_chromo, dtype='f')
		total_x = 0
		for x in range(len(Probab)):
			total_x += Probab[x]
			C[x] = total_x

#putar roulete whell sebanyak jumlah populasi yaitu 6 kali secara acak
		R = np.random.sample(len(fitness))
		chrom_baru = np.arange(jum_chromo*len(self.gen)).reshape(jum_chromo, len(self.gen))


#RUMUS UNTUK MENCARI CHROMOSOME BARU BERDASARKAN ROULETE WHELL
		for y in range(len(R)):
			for k in range(len(chrom_baru)):
				if(R[y] < C[0]):
					chrom_baru[y] = chrom[0]
				elif((C[k-1] < R[y]) & (R[y] < C[k])):
					chrom_baru[y] = chrom[k]

#MENCARI CROSSOVER chromosome
		R = np.random.sample(jum_chromo)
		index_chrom_parent = [] # [1,2,3, ...]
		for p in range(len(R)):
			if(R[p] < self.crossover_rate):
				index_chrom_parent.append(p)
                
#menentukan posisi crossover
		#membangkitkan bilangan acak dengan batasan 1 sampai (panjang chromosome-1), dalam kasus ini bilangan acak yang dibangkitkan adalah 1 – 3.
		posisi_cros = np.random.randint(low=1, high=len(self.gen), size=len(index_chrom_parent))

#menentukan posisi cut-point crossover
		offspring = np.arange(len(self.gen)*len(index_chrom_parent)).reshape(len(index_chrom_parent), len(self.gen))
		for i_parent in range(len(index_chrom_parent)):
			index_chrome_1 = index_chrom_parent[i_parent]
			if(i_parent == len(index_chrom_parent)-1):
				index_chrome_2 = index_chrom_parent[0]
			else:
				index_chrome_2 = index_chrom_parent[i_parent+1]
			#melakukan cut-point
			cut_point = posisi_cros[i_parent]
			for p in range(len(chrom_baru[index_chrome_1])):
				#LOOPING BERDASARKAN GEN
				if(p >= posisi_cros[i_parent]):
					#JIKA GEN[P] LEBIH BESAR ATAU SAMA DENGAN BILANGAN ACAK[P],
					#MAKA DIGANTI DGN CHROMOSOME KE-2
					offspring[i_parent][p] = chrom_baru[index_chrome_2][p]
				else:
					offspring[i_parent][p] = chrom_baru[index_chrome_1][p]

		#PROSES CROSSOVER DISIMPAN PADA VARIABLE 'OFFSPRING'
		#MELAKUKAN PENGGABUNGAN OFFSPRING DENGAN chrom_baru
		for x in range(len(offspring)):
			chrom_baru[index_chrom_parent[x]] = offspring[x]
            
#mutasi chromosome
# Misal ρm kita tentukan 10% maka diharapkan ada 10% dari total_gen yang mengalami populasi:
# jumlah mutasi      = 0.1 * 24
# = 2.4
# = 2

		total_gen = len(chrom) * len(chrom[0])
		jum_mutasi = self.mutasi_rate * total_gen #rumus menghitung jumlah mutasi
		jum_mutasi = int(jum_mutasi)

		random_i_mutasi = np.random.randint(low=0, high=total_gen, size=jum_mutasi)

		for x in range(len(random_i_mutasi)):
			index_mutasi = random_i_mutasi[x]
			byk_kromosom = len(chrom)
			byk_gen = len(chrom[0])
			random_value = random.randint(self.nilai_per_gen['min'], self.nilai_per_gen['max'])
			if(index_mutasi <= byk_gen):
				#jika index_mutasi <= banyak gen, maka akan mengganti
				#gen pada chromosome baru yang ke-0
				chrom_baru[0][index_mutasi-1]
			else:
				#POSISI Y DARI KROMOSOM, UNTUK MENCARI INDEX
				posisi_y = index_mutasi/byk_gen
				posisi_y = int(posisi_y)
				posisi_x = index_mutasi % byk_gen
				chrom_baru[posisi_y][posisi_x] = random_value
		return chrom_baru

	def do_now(self):
		chromosome_current = self.first_chrom
		for generasi in range(0, self.total_gen):
			if(self.stop != True):
				chromosome_current = self.evaluasi_chrom(chromosome_current, generasi)
		print("----------------------------------------------------------------------")
		print("ALL DONE!")
		print("CHROMOSOME TERTINGGI DAN TERBAIK ADALAH")
		print(self.next_gen)

run = Algoritma_genetika()
run.do_now()
# Out:
# ==================================================inisialisasi=================================================
# [[1 4 8 3]
#  [6 6 6 8]
#  [7 3 4 3]
#  [8 5 9 9]
#  [2 3 1 5]
#  [1 3 4 5]]
# ---------------------------------------------------------------------------------------------------------------
# GENERASI [1] ------
# CHROMOSOME 1 : [1,4,8,3], fitness = 0.0625
# CHROMOSOME 2 : [6,6,6,8], fitness = 0.02564102564102564
# CHROMOSOME 3 : [7,3,4,3], fitness = 0.125
# CHROMOSOME 4 : [8,5,9,9], fitness = 0.019230769230769232
# CHROMOSOME 5 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 6 : [1,3,4,5], fitness = 0.1
# FITNESS SELESAI!!
# [15 38  7 51  1  9]
# Total fitness : 0.83237183
# Rata-rata fitness : 0.13872863
# Probabilitas : [0.07508664,0.03080477,0.15017328,0.02310358,0.6006931 ,0.12013862]
# Probabilitas Paling Tinggi : 0.6006931066513062, Pada chromosome ke 5
# CHROMOSOME YANG MUNGKIN TERPILIH : [2,3,1,5]
#
#
# GENERASI [2] ------
# CHROMOSOME 1 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 2 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 3 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 4 : [2,3,4,5], fitness = 0.09090909090909091
# CHROMOSOME 5 : [1,3,4,3], fitness = 0.5
# CHROMOSOME 6 : [7,3,1,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [ 1  1  1 10  1  2]
# Total fitness : 2.4242423
# Rata-rata fitness : 0.40404037
# Probabilitas : [0.20625001,0.20625001,0.20625001,0.03750001,0.20625001,0.13750002]
# Probabilitas Paling Tinggi : 0.20625001192092896, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [2,3,1,5]
#
#
# GENERASI [3] ------
# CHROMOSOME 1 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 2 : [2,3,1,3], fitness = 0.125
# CHROMOSOME 3 : [1,3,4,9], fitness = 0.038461538461538464
# CHROMOSOME 4 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [0,3,1,5], fitness = 0.5
# FITNESS SELESAI!!
# [ 6  7 25  1  2  1]
# Total fitness : 1.639652
# Rata-rata fitness : 0.27327535
# Probabilitas : [0.08712651,0.07623569,0.02345714,0.30494276,0.20329517,0.30494276]
# Probabilitas Paling Tinggi : 0.3049427568912506, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [2,3,1,5]
#
#
# GENERASI [4] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 3 : [4,3,1,3], fitness = 0.16666666666666666
# CHROMOSOME 4 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 5 : [2,3,1,3], fitness = 0.125
# CHROMOSOME 6 : [4,3,1,5], fitness = 0.25
# FITNESS SELESAI!!
# [2 6 5 1 7 3]
# Total fitness : 1.5178572
# Rata-rata fitness : 0.2529762
# Probabilitas : [0.21960784,0.09411765,0.10980392,0.32941175,0.08235294,0.16470587]
# Probabilitas Paling Tinggi : 0.32941174507141113, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [2,3,1,5]
#
#
# GENERASI [5] ------
# CHROMOSOME 1 : [4,3,1,5], fitness = 0.25
# CHROMOSOME 2 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 3 : [3,4,1,3], fitness = 0.2
# CHROMOSOME 4 : [2,3,1,5], fitness = 0.5
# CHROMOSOME 5 : [4,3,1,5], fitness = 0.25
# CHROMOSOME 6 : [7,3,1,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [3 2 4 1 3 2]
# Total fitness : 1.8666667
# Rata-rata fitness : 0.31111112
# Probabilitas : [0.13392857,0.17857143,0.10714286,0.26785713,0.13392857,0.17857143]
# Probabilitas Paling Tinggi : 0.2678571343421936, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [2,3,1,5]
#
#
# GENERASI [6] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 3 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 4 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 5 : [2,3,1,9], fitness = 0.05555555555555555
# CHROMOSOME 6 : [4,3,2,5], fitness = 0.14285714285714285
# FITNESS SELESAI!!
# [ 2  6  2  2 17  6]
# Total fitness : 1.34127
# Rata-rata fitness : 0.223545
# Probabilitas : [0.24852069,0.10650887,0.24852069,0.24852069,0.04142011,0.10650887]
# Probabilitas Paling Tinggi : 0.24852068722248077, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,3,1,3]
#
#
# GENERASI [7] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [7,3,4,3], fitness = 0.125
# CHROMOSOME 3 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 4 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 5 : [4,3,1,3], fitness = 0.16666666666666666
# CHROMOSOME 6 : [7,3,1,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [2 7 6 2 5 2]
# Total fitness : 1.4345238
# Rata-rata fitness : 0.2390873
# Probabilitas : [0.23236515,0.08713693,0.09958506,0.23236515,0.11618257,0.23236515]
# Probabilitas Paling Tinggi : 0.23236514627933502, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,3,1,3]
#
#
# GENERASI [8] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 3 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 4 : [1,3,1,3], fitness = 0.1111111111111111
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [7,3,1,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [2 2 6 8 2 2]
# Total fitness : 1.5873016
# Rata-rata fitness : 0.26455027
# Probabilitas : [0.21000001,0.21000001,0.09      ,0.07      ,0.21000001,0.21000001]
# Probabilitas Paling Tinggi : 0.21000000834465027, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,3,1,3]
#
#
# GENERASI [9] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 3 : [4,3,1,9], fitness = 0.05
# CHROMOSOME 4 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [7,3,1,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [ 2  6 19  2  2  2]
# Total fitness : 1.5261906
# Rata-rata fitness : 0.25436512
# Probabilitas : [0.21840872,0.09360374,0.03276131,0.21840872,0.21840872,0.21840872]
# Probabilitas Paling Tinggi : 0.2184087187051773, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [7,3,1,3]
#
#
# GENERASI [10] ------
# CHROMOSOME 1 : [7,3,1,5], fitness = 0.14285714285714285
# CHROMOSOME 2 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 3 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 4 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [6 2 2 2 2 1]
# Total fitness : 1.9761906
# Rata-rata fitness : 0.3293651
# Probabilitas : [0.07228915,0.16867469,0.16867469,0.16867469,0.16867469,0.25301203]
# Probabilitas Paling Tinggi : 0.2530120313167572, Pada chromosome ke 6
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [11] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 3 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 4 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [7,3,9,3], fitness = 0.043478260869565216
# FITNESS SELESAI!!
# [ 1  2  2  2  2 22]
# Total fitness : 1.8768117
# Rata-rata fitness : 0.31280196
# Probabilitas : [0.26640925,0.17760617,0.17760617,0.17760617,0.17760617,0.02316602]
# Probabilitas Paling Tinggi : 0.2664092481136322, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [12] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 3 : [8,3,9,3], fitness = 0.041666666666666664
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [7,3,1,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [ 2  2 23  1  2  2]
# Total fitness : 1.8750001
# Rata-rata fitness : 0.31250003
# Probabilitas : [0.17777777,0.17777777,0.02222222,0.26666665,0.17777777,0.17777777]
# Probabilitas Paling Tinggi : 0.2666666507720947, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [13] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [8,3,1,6], fitness = 0.08333333333333333
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [7,3,7,3], fitness = 0.058823529411764705
# FITNESS SELESAI!!
# [ 2  1  1 11  2 16]
# Total fitness : 1.8088237
# Rata-rata fitness : 0.3014706
# Probabilitas : [0.18428183,0.27642274,0.27642274,0.04607046,0.18428183,0.03252032]
# Probabilitas Paling Tinggi : 0.27642273902893066, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [14] ------
# CHROMOSOME 1 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,7,3], fitness = 0.05555555555555555
# CHROMOSOME 4 : [7,3,1,9], fitness = 0.043478260869565216
# CHROMOSOME 5 : [7,3,7,3], fitness = 0.058823529411764705
# CHROMOSOME 6 : [8,3,2,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [ 2  1 17 22 16  2]
# Total fitness : 1.324524
# Rata-rata fitness : 0.22075401
# Probabilitas : [0.25166273,0.3774941 ,0.04194379,0.03282557,0.04441107,0.25166273]
# Probabilitas Paling Tinggi : 0.37749409675598145, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [15] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,2,4], fitness = 0.14285714285714285
# FITNESS SELESAI!!
# [1 2 1 1 1 6]
# Total fitness : 2.4761906
# Rata-rata fitness : 0.41269842
# Probabilitas : [0.20192307,0.13461538,0.20192307,0.20192307,0.20192307,0.05769231]
# Probabilitas Paling Tinggi : 0.20192307233810425, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [16] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [1,3,1,3], fitness = 0.1111111111111111
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [7,3,1,3], fitness = 0.3333333333333333
# CHROMOSOME 6 : [8,3,1,2], fitness = 0.16666666666666666
# FITNESS SELESAI!!
# [1 1 8 1 2 5]
# Total fitness : 2.1111112
# Rata-rata fitness : 0.35185185
# Probabilitas : [0.2368421 ,0.2368421 ,0.05263158,0.2368421 ,0.15789473,0.07894737]
# Probabilitas Paling Tinggi : 0.2368420958518982, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [17] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [1,3,1,3], fitness = 0.1111111111111111
# CHROMOSOME 4 : [8,5,1,3], fitness = 0.25
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [1 1 8 3 1 1]
# Total fitness : 2.3611112
# Rata-rata fitness : 0.39351854
# Probabilitas : [0.21176471,0.21176471,0.04705882,0.10588235,0.21176471,0.21176471]
# Probabilitas Paling Tinggi : 0.21176470816135406, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [18] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [1 1 1 1 1 1]
# Total fitness : 3.0
# Rata-rata fitness : 0.5
# Probabilitas : [0.16666667,0.16666667,0.16666667,0.16666667,0.16666667,0.16666667]
# Probabilitas Paling Tinggi : 0.1666666716337204, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [19] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [ 8,10, 1, 3], fitness = 0.07142857142857142
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,2,3], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [ 1  1  1 13  1  2]
# Total fitness : 2.4047618
# Rata-rata fitness : 0.40079364
# Probabilitas : [0.2079208 ,0.2079208 ,0.2079208 ,0.02970297,0.2079208 ,0.13861386]
# Probabilitas Paling Tinggi : 0.20792080461978912, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [20] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [ 8,10, 1, 3], fitness = 0.07142857142857142
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [ 1  1 13  1  1  1]
# Total fitness : 2.5714285
# Rata-rata fitness : 0.42857143
# Probabilitas : [0.19444445,0.19444445,0.02777778,0.19444445,0.19444445,0.19444445]
# Probabilitas Paling Tinggi : 0.1944444477558136, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [21] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,1,0], fitness = 0.07142857142857142
# FITNESS SELESAI!!
# [ 1  1  1  1  1 13]
# Total fitness : 2.5714285
# Rata-rata fitness : 0.42857143
# Probabilitas : [0.19444445,0.19444445,0.19444445,0.19444445,0.19444445,0.02777778]
# Probabilitas Paling Tinggi : 0.1944444477558136, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [22] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [1 1 1 1 1 1]
# Total fitness : 3.0
# Rata-rata fitness : 0.5
# Probabilitas : [0.16666667,0.16666667,0.16666667,0.16666667,0.16666667,0.16666667]
# Probabilitas Paling Tinggi : 0.1666666716337204, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [23] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,5,1,3], fitness = 0.25
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [1 1 3 1 1 1]
# Total fitness : 2.75
# Rata-rata fitness : 0.45833334
# Probabilitas : [0.18181819,0.18181819,0.09090909,0.18181819,0.18181819,0.18181819]
# Probabilitas Paling Tinggi : 0.1818181872367859, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# GENERASI [24] ------
# CHROMOSOME 1 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 2 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 3 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 4 : [8,3,1,3], fitness = 0.5
# CHROMOSOME 5 : [8,5,1,3], fitness = 0.25
# CHROMOSOME 6 : [8,3,1,3], fitness = 0.5
# FITNESS SELESAI!!
# [1 1 1 1 3 1]
# Total fitness : 2.75
# Rata-rata fitness : 0.45833334
# Probabilitas : [0.18181819,0.18181819,0.18181819,0.18181819,0.09090909,0.18181819]
# Probabilitas Paling Tinggi : 0.1818181872367859, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [8,3,1,3]
#
#
# ----------------------------------------------------------------------
# ALL DONE!
# CHROMOSOME TERTINGGI DAN TERBAIK ADALAH
# [8 3 1 3]
